# %% [markdown]
# #### 참고로
# - to_categorical을 통해 정수를 이진벡터로 만들었는데
# - 이진벡터를 정수 스칼라로 역변환 할 때는
#     - np.argmax(Y_train, axis=1)을 쓰면 최댓값의 index를 찾아준다

# %%
import numpy as np
from keras import datasets
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
def Data_func():
    (X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
    
    Y_train = np_utils.to_categorical(y_train)
    Y_test = np_utils.to_categorical(y_test)
    
    L, W, H, C = X_train.shape
    X_train = X_train.reshape(-1, W * H * C)
    X_test = X_test.reshape(-1, W * H * C)
    
    X_train = X_train / 255.0
    X_test = X_test /  255.0
    
    return (X_train, Y_train), (X_test, Y_test)

# %%
from keras import layers, models

class DNN(models.Sequential):
    def __init__(self, Nin, Nh_l, Pd_l, Nout):
        super().__init__()
        
        self.add(layers.Dense(Nh_l[0], activation='relu', input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dropout(Pd_l[0]))
        
        self.add(layers.Dense(Nh_l[1], activation='relu', name='Hidden-2'))
        self.add(layers.Dropout(Pd_l[1]))
        
        self.add(layers.Dense(Nout, activation='softmax'))
        
        self.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keraspp.skeras import plot_loss, plot_acc
import matplotlib.pyplot as plt

def main():
    Nh_l = [150 ,100]
    # Pd_l = [0.0, 0.0] # dropout 없이 하면 training, validation loss/acc이 차이가 많이난다
    Pd_l = [0.02, 0.05]
    number_of_class = 10
    Nout = number_of_class
    
    (X_train, Y_train), (X_test, Y_test) = Data_func()
    model = DNN(X_train.shape[1], Nh_l, Pd_l, Nout)
    history = model.fit(X_train, Y_train, epochs=10, batch_size=100, validation_split=0.2)
    
    performance_test = model.evaluate(X_test, Y_test, batch_size=100)
    print('Test Loss and Accuracy ->', performance_test)
    
    plot_acc(history)
    plt.show()
    
    plot_loss(history)
    plt.show()

# %%
main()
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 63us/step - loss: 1.9232 - acc: 0.3023 - val_loss: 1.8230 - val_acc: 0.3356
# Epoch 2/10
# 40000/40000 [==============================] - 2s 57us/step - loss: 1.7509 - acc: 0.3714 - val_loss: 1.7274 - val_acc: 0.3818
# Epoch 3/10
# 40000/40000 [==============================] - 2s 57us/step - loss: 1.6779 - acc: 0.3994 - val_loss: 1.6360 - val_acc: 0.4192
# Epoch 4/10
# 40000/40000 [==============================] - 2s 55us/step - loss: 1.6334 - acc: 0.4173 - val_loss: 1.6260 - val_acc: 0.4169
# Epoch 5/10
# 40000/40000 [==============================] - 2s 56us/step - loss: 1.5925 - acc: 0.4299 - val_loss: 1.6167 - val_acc: 0.4196
# Epoch 6/10
# 40000/40000 [==============================] - 2s 53us/step - loss: 1.5698 - acc: 0.4365 - val_loss: 1.5668 - val_acc: 0.4428
# Epoch 7/10
# ...

# %% [markdown]
# ## 결과
# - Overfitting을 피하기 위해 적절한 Dropout이 필요할 수 있다.
# - 물론 조기 종료 및 1/2차 정규화 등을 이용해 overfitting을 방지할 수도 있다.
# - 데이터가 충분히 많다면 할필요가 없다.
